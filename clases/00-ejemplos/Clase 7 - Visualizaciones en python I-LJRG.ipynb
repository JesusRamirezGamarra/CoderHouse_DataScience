# %% [markdown]
# # CLASE 7 - Visualizaciones en python I
# ### Coderhouse - Data Science
# Profe Omar Muñoz

# %%
# importar librerias
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Interfaz orientada a objetos
fig, ax = plt.subplots() # crea el objeto del grafico
ax.plot([1, 3], [2, 4]) # grafica una linea

# %%
mpl.style.use('bmh') # define un estilo para todo el notebook
#mpl.style.use('tableau-colorblind10') #configuracion para daltonicos

# %% [markdown]
# > Acá puedes encontrar más estilos:
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %% [markdown]
# Repitamos la grafica previa con este nuevo estilo

# %%
fig, ax = plt.subplots()
ax.plot([1, 3], [2, 4])

# %%
fig, ax = plt.subplots()
ax.plot([1, 3], [2, 4])
# le asignamos al objeto nuevas propiedades
ax.set_xlabel("Unidades X") # nombre del eje X
ax.set_ylabel("Unidades Y") # nombre del eje Y
ax.set_title("Título") # título
ax.legend(['Leyenda']) # Muestra la leyenda y le asigna un nombre

# %%
# Cargamos los datos
df_lluvias = pd.read_csv('Source/pune_1965_to_2002.csv')
df_lluvias.head()
# Out:
#    Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# 0  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 2  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 3  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 4  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
#
#        Sep     Oct     Nov     Dec
# 0   69.511   5.249  16.232  22.075
# 1  150.624   1.308  41.214   4.132
# 2  183.757  50.404   8.393  37.685
# 3  219.884  73.997  23.326   2.020
# 4  205.413  24.014  24.385   1.951

# %%
# Asignamos un year como un indice
df_lluvias.index = df_lluvias['Year']#asignar al indice
df_lluvias.head(5)
# Out:
#       Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# Year
# 1965  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1966  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 1967  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 1968  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 1969  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
#
#           Sep     Oct     Nov     Dec
# Year
# 1965   69.511   5.249  16.232  22.075
# 1966  150.624   1.308  41.214   4.132
# 1967  183.757  50.404   8.393  37.685
# 1968  219.884  73.997  23.326   2.020
# 1969  205.413  24.014  24.385   1.951

# %%
#Eliminamos la columna porque ya forma parte del Indice ( columna Year )
df_lluvias = df_lluvias.drop('Year', axis='columns')#eliminar columna Year
df_lluvias.head(5)
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386  150.624
# 1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069  183.757
# 1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979  219.884
# 1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335  205.413
#
#          Oct     Nov     Dec
# Year
# 1965   5.249  16.232  22.075
# 1966   1.308  41.214   4.132
# 1967  50.404   8.393  37.685
# 1968  73.997  23.326   2.020
# 1969  24.014  24.385   1.951

# %%
# Asignamos los datos que queremos graficar
x = df_lluvias.index # Indice es la columna Year
y = df_lluvias.sum(axis='columns') #lluvia x Year
x
# Out:
# Int64Index([1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#             1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#             1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002],
#            dtype='int64', name='Year')

# %%
y.head(5)
# Out:
# Year
# 1965    1263.394
# 1966     899.588
# 1967    1522.184
# 1968    1086.237
# 1969    1739.022
# dtype: float64

# %%
#fig, ax = plt.subplots(figsize=(12, 4)) # (6, 6) # figsize es el tamaño de la figura (ancho, alto)
#fig, ax = plt.subplots(figsize=(6,6)) # (6, 6) # figsize es el tamaño de la figura (ancho, alto)
fig, ax = plt.subplots(figsize=(16, 4)) # (6, 6) # figsize es el tamaño de la figura (ancho, alto)
#fig, ax = plt.subplots()
ax.plot(x, y, label='Precipitaciones acumuladas')
ax.set_xlabel('Año') 
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend() #loc='upper right' #'lower center' #best #'right'
ax.legend(loc='lower center') #loc='upper right' #'lower center' #best #'right'
#ax.legend(loc='lower center') 
#ax.legend(loc='best') 
#ax.legend(loc='right')

# %%
# PRO TIP , nos brinda informacion del comando ejecutado.
ax.legend?

# %%
#ymin = df_lluvias.sum(axis='columns').min()
#ymax = df_lluvias.sum(axis='columns').max()

fig, ax = plt.subplots(figsize=(16, 4))
ax.plot(x, y, label='Precipitaciones acumuladas')
ax.set_xlabel('Año') 
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend()
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1]) # límites del eje x  , para ajustar el grafico a los valores de X
ax.set_ylim(650, 2100) # límites del eje y
# Out:
# (650.0, 2100.0)

# %%
ymin = df_lluvias.sum(axis='columns').min()
ymax = df_lluvias.sum(axis='columns').max()
#fig, ax = plt.subplots(figsize=(12, 4)) # (6, 6) # figsize es el tamaño de la figura (ancho, alto)
#fig, ax = plt.subplots(figsize=(6,6)) # (6, 6) # figsize es el tamaño de la figura (ancho, alto)
fig, ax = plt.subplots(figsize=(16, 4)) # (6, 6) # figsize es el tamaño de la figura (ancho, alto)
#fig, ax = plt.subplots()
ax.plot(x, y, label='Precipitaciones acumuladas')
ax.set_xlabel('Año') 
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend() #loc='upper right' #'lower center' #best #'right'
ax.legend(loc='lower center') #loc='upper right' #'lower center' #best #'right'
#ax.legend(loc='lower center') 
#ax.legend(loc='best') 
#ax.legend(loc='right') 
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1]) # límites del eje x  , para ajustar el grafico a los valores de X
ax.set_ylim(ymin, ymax) # límites del eje x  , para ajustar el grafico a los valores de X
# Out:
# (710.4749999999999, 1987.6889999999999)

# %%
df_lluvias.sum(axis='columns').min()
# Out:
# 2682.475

# %%
df_lluvias.sum(axis='columns').max()
# Out:
# 3981.689

# %%
df_lluvias.sum(axis='columns')
# Out:
# 0     3228.394
# 1     2865.588
# 2     3489.184
# 3     3054.237
# 4     3708.022
# 5     3243.507
# 6     3147.612
# 7     2682.475
# 8     3543.073
# 9     3399.876
# 10    3752.838
# 11    3917.167
# 12    3179.154
# 13    3146.583
# 14    3748.187
# 15    3248.185
# 16    3543.761
# 17    2925.087
# 18    3599.948
# 19    3522.961
# 20    3199.852
# 21    3253.969
# 22    3184.999
# 23    3810.649
# 24    3389.024
# 25    3756.294
# 26    3488.256
# 27    3315.883
# 28    3203.252
# 29    3981.689
# 30    3204.068
# 31    3627.331
# 32    3841.840
# 33    3601.243
# 34    3234.683
# 35    3094.062
# 36    3046.825
# 37    3026.881
# dtype: float64

# %%
fig.savefig("precipitaciones_año.pdf") # guardar figura en pdf

# %%
fig.savefig("precipitaciones_año.png") # guardar figura en png

# %%
#hoja de truco para ver q se puede modificar de un grafico

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ejemplos premier league

# %%
df = pd.read_csv("df_full_premierleague.csv", index_col=0)
df.head()
# Out:
#                                  link_match season        date  \
# 0  https://www.premierleague.com/match/7186  10/11  2010-11-01
# 1  https://www.premierleague.com/match/7404  10/11  2011-04-11
# 2  https://www.premierleague.com/match/7255  10/11  2010-12-13
# 3  https://www.premierleague.com/match/7126  10/11  2010-09-13
# 4  https://www.premierleague.com/match/7350  10/11  2011-02-14
#
#            home_team             away_team result_full result_ht  \
# 0          Blackpool  West Bromwich Albion         2-1       1-0
# 1          Liverpool       Manchester City         3-0       3-0
# 2  Manchester United               Arsenal         1-0       1-0
# 3         Stoke City           Aston Villa         2-1       0-1
# 4             Fulham               Chelsea         0-0       0-0
#
#    home_clearances  home_corners  home_fouls_conceded  ...  tackles_avg_away  \
# 0             15.0           8.0                 16.0  ...              20.0
# 1             16.0           6.0                  6.0  ...              22.0
# 2             26.0           5.0                  9.0  ...              21.2
# 3             26.0           8.0                 12.0  ...              25.0
# 4             50.0           4.0                 11.0  ...              19.4
#
#    touches_avg_away  yellow_cards_avg_away  goals_scored_ft_avg_away  \
# 0             584.9                    1.6                      1.44
# 1             681.4                    2.0                      1.61
# 2             748.0                    1.8                      2.12
# 3             567.3                    2.0                      1.33
# 4             728.6                    1.4                      1.84
#
#    goals_conced_ft_avg_away  sg_match_ft_acum_away  goals_scored_ht_avg_away  \
# 0                      1.67                   -2.0                      0.33
# 1                      0.87                   23.0                      0.87
# 2                      1.12                   16.0                      0.94
# 3                      2.00                   -2.0                      1.00
# 4                      0.88                   24.0                      0.84
#
#    goals_conced_ht_avg_away  sg_match_ht_acum_away  performance_acum_away
# 0                      0.78                   -4.0                   55.6
# 1                      0.32                   17.0                   60.2
# 2                      0.38                    9.0                   66.7
# 3                      1.00                    0.0                   66.7
# 4                      0.48                    9.0                   58.7
#
# [5 rows x 113 columns]

# %%
df.columns
# Out:
# Index(['link_match', 'season', 'date', 'home_team', 'away_team', 'result_full',
#        'result_ht', 'home_clearances', 'home_corners', 'home_fouls_conceded',
#        ...
#        'tackles_avg_away', 'touches_avg_away', 'yellow_cards_avg_away',
#        'goals_scored_ft_avg_away', 'goals_conced_ft_avg_away',
#        'sg_match_ft_acum_away', 'goals_scored_ht_avg_away',
#        'goals_conced_ht_avg_away', 'sg_match_ht_acum_away',
#        'performance_acum_away'],
#       dtype='object', length=113)

# %%
# Convertimos la columna date a formato fecha
df['date'] = pd.to_datetime(df['date'])



#######################################################################
# Creamos una columna con los puntos por partido de local
df.home_points = 0
# Asignamos 3 puntos al local cuando anota más goles que el visitante
df.loc[df['goal_home_ft'] > df['goal_away_ft'], 'home_points'] = 3 
# Asignamos 1 puntos al local cuando anota lo mismo que el visitante
df.loc[df['goal_home_ft'] == df['goal_away_ft'], 'home_points'] = 1
# Asignamos 0 puntos al local cuando anota menos goles que el visitante
df.loc[df['goal_away_ft'] > df['goal_home_ft'], 'home_points'] = 0

# Creamos una columna con los puntos por partido de visitante
df.away_points = 3
df.loc[df['goal_home_ft'] > df['goal_away_ft'], 'away_points'] = 0
df.loc[df['goal_home_ft'] == df['goal_away_ft'], 'away_points'] = 1
df.loc[df['goal_away_ft'] > df['goal_home_ft'], 'away_points'] = 3
#######################################################################


# Creamos una columna con los puntos por partido totales
df['total_points'] = df['home_points'] + df['away_points']

# %% [markdown]
# # Gráficos de líneas

# %%
Liverpool.index
# Out:
# Int64Index([3282, 3056, 3193, 3076, 3116, 3177, 3215, 3355, 3158, 3205, 3223,
#             3279, 3188, 3310, 3412, 3250, 3299, 3041, 3395, 3211, 3359, 3091,
#             3129, 3409, 3062, 3262, 3324, 3402, 3338, 3276, 3304, 3347, 3047,
#             3297, 3317, 3044, 3238, 3289],
#            dtype='int64')

# %%
# Filtrar los partidos del Liverpool de local y de visitante
# Liverpool df [ (filtro == condiciones ) ] [ [Columna 1 ,Columna n]] . Sort_values(by='date')
Liverpool = df[  ( df['season']=='18/19')&
      (( df['home_team']=='Liverpool')|
       ( df['away_team']=='Liverpool'))]   [   ['date', 'total_points']  ].sort_values(by="date") # ordenarlos por fecha

Liverpool
# Out:
#            date  total_points
# 3282 2018-08-12           3.0
# 3056 2018-08-20           3.0
# 3193 2018-08-25           3.0
# 3076 2018-09-01           3.0
# 3116 2018-09-15           3.0
# 3177 2018-09-22           3.0
# 3215 2018-09-29           2.0
# 3355 2018-10-07           2.0
# 3158 2018-10-20           3.0
# 3205 2018-10-27           3.0
# 3223 2018-11-03           2.0
# 3279 2018-11-11           3.0
# 3188 2018-11-24           3.0
# 3310 2018-12-02           3.0
# 3412 2018-12-05           3.0
# 3250 2018-12-08           3.0
# 3299 2018-12-16           3.0
# 3041 2018-12-21           3.0
# 3395 2018-12-26           3.0
# 3211 2018-12-29           3.0
# 3359 2019-01-03           3.0
# 3091 2019-01-12           3.0
# 3129 2019-01-19           3.0
# 3409 2019-01-30           2.0
# 3062 2019-02-04           2.0
# 3262 2019-02-09           3.0
# 3324 2019-02-24           2.0
# 3402 2019-02-27           3.0
# 3338 2019-03-03           2.0
# 3276 2019-03-10           3.0
# 3304 2019-03-17           3.0
# 3347 2019-03-31           3.0
# 3047 2019-04-05           3.0
# 3297 2019-04-14           3.0
# 3317 2019-04-21           3.0
# 3044 2019-04-26           3.0
# 3238 2019-05-04           3.0
# 3289 2019-05-12           3.0

# %%
# Filtrar los partidos del City de local y de visitante
City = df[ (df['season']=='18/19')&
           ( (df['home_team']=='Manchester City')|
             (df['away_team']=='Manchester City'))]  [['date', 'total_points']].sort_values(by="date")# ordenarlos por fecha
City
# Out:
#            date  total_points
# 3281 2018-08-12           3.0
# 3307 2018-08-19           3.0
# 3195 2018-08-25           2.0
# 3077 2018-09-01           3.0
# 3114 2018-09-15           3.0
# 3173 2018-09-22           3.0
# 3218 2018-09-29           3.0
# 3355 2018-10-07           2.0
# 3159 2018-10-20           3.0
# 3061 2018-10-29           3.0
# 3349 2018-11-04           3.0
# 3280 2018-11-11           3.0
# 3189 2018-11-24           3.0
# 3069 2018-12-01           3.0
# 3380 2018-12-04           3.0
# 3254 2018-12-08           3.0
# 3107 2018-12-15           3.0
# 3168 2018-12-22           3.0
# 3394 2018-12-26           3.0
# 3344 2018-12-30           3.0
# 3359 2019-01-03           3.0
# 3053 2019-01-14           3.0
# 3315 2019-01-20           3.0
# 3376 2019-01-29           3.0
# 3337 2019-02-03           3.0
# 3418 2019-02-06           3.0
# 3272 2019-02-10           3.0
# 3403 2019-02-27           3.0
# 3142 2019-03-02           3.0
# 3269 2019-03-09           3.0
# 3232 2019-03-30           3.0
# 3406 2019-04-03           3.0
# 3296 2019-04-14           3.0
# 3151 2019-04-20           3.0
# 3388 2019-04-24           3.0
# 3330 2019-04-28           3.0
# 3064 2019-05-06           3.0
# 3284 2019-05-12           3.0

# %%
# Calcular la suma acumulada de las series
Liverpool['acum'] = Liverpool['total_points'].cumsum()
City['acum'] = City['total_points'].cumsum()

# %%
Liverpool.head(5)
# Out:
#            date  total_points  acum
# 3282 2018-08-12           3.0   3.0
# 3056 2018-08-20           3.0   6.0
# 3193 2018-08-25           3.0   9.0
# 3076 2018-09-01           3.0  12.0
# 3116 2018-09-15           3.0  15.0

# %%
City.head(5)
# Out:
#            date  total_points  acum
# 3281 2018-08-12           3.0   3.0
# 3307 2018-08-19           3.0   6.0
# 3195 2018-08-25           2.0   8.0
# 3077 2018-09-01           3.0  11.0
# 3114 2018-09-15           3.0  14.0

# %%
fig, ax = plt.subplots(figsize=(16, 8)) 
ax.plot(City['date'], City['acum'], 'o-',label = 'Manchester City') # '0-' es para marcar los puntos
ax.plot(Liverpool['date'], Liverpool['acum'],'x-', label='Liverpool')

plt.xticks(rotation=90) # Rota los nombres 90 grados

ax.set_xlabel('Equipo visitante') 
ax.set_title('Puntos acumulados temporada 18/19 - Liverpool vs Manchester City')
#ax.legend(loc='lower center')
ax.legend(loc='best')

# %% [markdown]
# # Gráficos de puntos

# %% [markdown]
# ### Relación fuerte

# %%
# Seleccionamos las variables de posesión y pases en las temporadas de Guardiola
guardiola = ['16/17', '17/18', '18/19'] # lista para realizar filtro
# isin es un operador de pertenencia de pandas para indicar que elementos existene en
posesion_g = df[  (df['season'].isin(guardiola) ) & (df['home_team']=='Manchester City')] ['home_possession']

pases_g = df[  (df['season'].isin(guardiola)) & (df['home_team']=='Manchester City')] ['home_passes']

# %%
# Seleccionamos las variables de posesión y pases en las temporadas de Pellegrini
pellegrini = ['13/14', '14/15', '15/16']

posesion_p = df[(df['season'].isin(pellegrini))&(df['home_team']=='Manchester City')]['home_possession']
pases_p = df[(df['season'].isin(pellegrini))&(df['home_team']=='Manchester City')]['home_passes']

# %%
#scatter - Dispersion
fig, ax = plt.subplots(figsize=(12, 12))
# por cada "scatter" que se agregue se gráfica una línea
ax.scatter(posesion_g, pases_g, alpha=0.5)  #alpha controle la transparencia del punto
ax.scatter(posesion_p, pases_p, alpha=0.5)

ax.set_title('Manchester City de local')

ax.set_xlabel('% de posesión del balón')
ax.set_ylabel('No. de pases por partido')

ax.legend(['Guardiola', 'Pellegrini'], loc='upper left')

# Interpretacion
# Los puntos estan unidos , la forma es como de un espiral con tendencia a estar lijeramente cercana . 
# Eso indica que es una relacion fuerte  
# Si la nube de puntos estuviera muy dispersa se dice que tiene una relacion debil

# %% [markdown]
# ### Relación débil

# %%
guardiola = ['16/17', '17/18', '18/19'] # Creamos una lista con las temporadas de Guardiola
# Creamos una serie que guarde los datos que cumplen 2 condiciones:
# 1) que las temporadas esten en la lista y 2) que el equipo de local sea el Man. City
posesion_g = df[(df['season'].isin(guardiola))&(df['home_team']=='Manchester City')]['home_possession']
goles_g = df[(df['season'].isin(guardiola))&(df['home_team']=='Manchester City')]['goal_home_ft']

pellegrini = ['13/14', '14/15', '15/16'] # Creamos una lista con las temporadas de Guardiola
posesion_p = df[(df['season'].isin(pellegrini))&(df['home_team']=='Manchester City')]['home_possession']
goles_p = df[(df['season'].isin(pellegrini))&(df['home_team']=='Manchester City')]['goal_home_ft']

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(posesion_g, goles_g, alpha=0.7)
ax.scatter(posesion_p, goles_p, alpha=0.7)
ax.set_title('Manchester City de local')
ax.set_xlabel('% de posesión del balón')
ax.set_ylabel('No. de goles por partido')
ax.legend(['Guardiola', 'Pellegrini'], loc='upper left')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Gráficos de barras

# %%
equipos         = df[  ( df['season']=='18/19') & (df['home_team']=='Liverpool')]  ['away_team']
disparos        = df[  ( df['season']=='18/19') & (df['home_team']=='Liverpool')]  ['home_shots']
disparosPuerta  = df[  ( df['season']=='18/19') & (df['home_team']=='Liverpool')]  ['home_shots_on_target']
goles           = df[  ( df['season']=='18/19') & (df['home_team']=='Liverpool')]  ['goal_home_ft']

# %%
fig, ax = plt.subplots(figsize=(16, 8)) 

ax.bar(equipos, disparos,        label = 'Disparos totales',  width = 0.75) # width es el ancho de la barra
ax.bar(equipos, disparosPuerta,  label = 'Disparos a puerta', width = 0.5)
ax.bar(equipos, goles,           label = 'Goles',             width = 0.25)

plt.xticks(rotation=90) # Rota los nombres 90 grados
ax.set_xlabel('Equipo visitante') 
ax.set_ylabel('# Goles')
ax.set_title('Liverpool de local - 18/19')
ax.legend()

# %% [markdown]
# # Histograma

# %%
#df.values.flatten() , convierte un matriz (x,y) en una serie ( X0,X1,X2,...)
# a0 a1
# b0 b1 
# flatter() => a0,a1,b0,b1

fig, ax = plt.subplots(figsize=(16, 8))
ax.hist(df.goal_home_ft)

ax.set_title('Histograma goles de local Premier League')
ax.set_xlabel('Cantidad de goles de local')
ax.set_ylabel('Frecuencia absoluta')
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %% [markdown]
# También se puede usar para comparar

# %%
fig, ax = plt.subplots(figsize=(16, 8))

ax.hist(df[df['home_team']=='Arsenal']['home_passes'], label = 'Arsenal', bins=30, alpha=0.7)
ax.hist(df[df['home_team']=='Aston Villa']['home_passes'], label = 'Aston Villa', bins=30, alpha=0.7)


ax.set_title('Histograma pases equipos Premier League')
ax.set_xlabel('Cantidad de pases de local')
ax.set_ylabel('Frecuencia absoluta')
ax.legend()

# %% [markdown]
# # Enriqueciendo visualizaciones

# %% [markdown]
# ### Líneas o bandas

# %%
fig, ax = plt.subplots(figsize=(8, 12)) 

ax.barh(equipos, disparosPuerta, label = 'Disparos a puerta')

ax.set_ylabel('Equipo visitante') 
ax.set_title('Liverpool de local - 18/19')


# vlines se usa para líneas verticales
# linestyle es el estilo de la línea, por defecto es continuo
# alpha es la transparencia de la línea
# linewidth es el ancho de la línea
ax.vlines(disparosPuerta.mean(), ymin = -1, ymax = 19, color='red', linestyle=':', 
          alpha=0.5, linewidth=5, label='Promedio')

ax.vlines(disparosPuerta.mean() +disparosPuerta.std(), ymin = -1, ymax = 19, color='green', linestyle='--', 
          alpha=0.5, linewidth=3, label='Promedio+std')

ax.vlines(disparosPuerta.mean() -disparosPuerta.std(), ymin = -1, ymax = 19, color='green', linestyle='--', 
          alpha=0.5, linewidth=3, label='Promedio-std')

ax.legend()

# %%
fig, ax = plt.subplots(figsize=(12, 8)) 

ax.bar(equipos, disparosPuerta, label = 'Disparos a puerta')

ax.set_ylabel('Equipo visitante') 
ax.set_title('Liverpool de local - 18/19')


# vlines se usa para líneas verticales
# linestyle es el estilo de la línea, por defecto es continuo
# alpha es la transparencia de la línea
# linewidth es el ancho de la línea
ax.axhline(disparosPuerta.mean(), color='red', linestyle=':', 
           alpha=0.5, linewidth=3, label='Promedio')

ax.axhline(disparosPuerta.mean() +disparosPuerta.std(), color='green', linestyle='--', 
          alpha=0.5, linewidth=3, label='Promedio+std')

ax.axhline(disparosPuerta.mean() -disparosPuerta.std(), color='green', linestyle='--', 
          alpha=0.5, linewidth=3, label='Promedio-std')

plt.xticks(rotation=90)

ax.legend()

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
ax.bar(equipos, goles, label = 'Disparos a puerta')
ax.set_ylabel('Equipo visitante') 
ax.set_title('Liverpool de local - 18/19')
# axhline se usa para líneas horizontales
ax.axhline(goles.mean(), color='green', linestyle=':', alpha=0.5, linewidth=3, label='Promedio')
ax.axhline(goles.mean()+goles.std(), color='green', linestyle=':', alpha=0.5, linewidth=3, label='Promedio+std')
ax.axhline(goles.mean()-goles.std(), color='green', linestyle=':', alpha=0.5, linewidth=3, label='Promedio-std')
plt.xticks(rotation=90)
ax.legend()
